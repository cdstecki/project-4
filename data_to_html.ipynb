# %%
from tabulate import tabulate
import pandas as pd

# %%
csv = 'Resources/data/data_cleaned_2021.csv'

salary_data = pd.read_csv(csv)
salary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               742 non-null    int64
#  1   Job Title           742 non-null    object
#  2   Salary Estimate     742 non-null    object
#  3   Job Description     742 non-null    object
#  4   Rating              742 non-null    float64
#  5   Company Name        742 non-null    object
#  6   Location            742 non-null    object
#  7   Headquarters        742 non-null    object
#  8   Size                742 non-null    object
#  9   Founded             742 non-null    int64
#  10  Type of ownership   742 non-null    object
#  11  Industry            742 non-null    object
#  12  Sector              742 non-null    object
#  13  Revenue             742 non-null    object
#  14  Competitors         742 non-null    object
# ...

# %%
salary_html = salary_data[['Job Title', 'Job Location', 'company_txt', 'Location', 'Industry', 'Lower Salary', 'Upper Salary', 'Avg Salary(K)', 'Degree']].copy()
salary_html.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Job Title      742 non-null    object
#  1   Job Location   742 non-null    object
#  2   company_txt    742 non-null    object
#  3   Location       742 non-null    object
#  4   Industry       742 non-null    object
#  5   Lower Salary   742 non-null    int64
#  6   Upper Salary   742 non-null    int64
#  7   Avg Salary(K)  742 non-null    float64
#  8   Degree         742 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 52.3+ KB

# %%
html = salary_html.to_html()
print(html)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 html = salary_html.to_html()
#       2 print(html)
#
# NameError: name 'salary_html' is not defined

# %%
--ServerApp.iopub_data_rate_limit=10000000
# Out:
#   Input In [32]
#     --ServerApp.iopub_data_rate_limit=10000000
#     ^
# SyntaxError: cannot assign to operator

# %%
# !pip install flask_pymongo

# %%
data_df = pd.read_csv('Resources/data/data_trimmed.csv')

# %%
data_df
# Out:
#      Unnamed: 0    job_title_sim Job Location  Grouped_Rating  Avg_Salary  \
# 0             0   data scientist           NM             4.0        72.0
# 1             1   data scientist           MD             3.5        87.5
# 2             2   data scientist           FL             5.0        85.0
# 3             3   data scientist           WA             4.0        76.5
# 4             4   data scientist           NY             3.0       114.5
# ..          ...              ...          ...             ...         ...
# 737         737  other scientist           MA             4.0        84.5
# 738         738    data engineer           TN             4.5       102.5
# 739         739  other scientist           PA             3.0        73.5
# 740         740   data scientist           PA             3.5       127.5
# 741         741  other scientist           OH             4.0        93.5
#
#                            Sector       Type of ownership  \
# ...

# %%
titles = data_df['job_title_sim'].copy()
titles = pd.DataFrame(titles.unique())
titles
# Out:
#                                 0
# 0                  data scientist
# 1                 other scientist
# 2                         analyst
# 3                   data engineer
# 4                  data analitics
# 5                              na
# 6                    data modeler
# 7  Data scientist project manager
# 8       machine learning engineer
# 9                        director

# %%
title_html = titles.to_html()
print(title_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>data scientist</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>other scientist</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>analyst</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>data engineer</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>data analitics</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>na</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>data modeler</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Data scientist project manager</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>machine learning engineer</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>director</td>
#     </tr>
#   </tbody>
# </table>

# %%
states = pd.DataFrame(data_df['Job Location'].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [58], in <cell line: 3>()
#       1 states = pd.DataFrame(data_df['Job Location'].unique())
# ----> 3 states = states.sort_values('0').reset_index(drop=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6313, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6309 elif len(by):
#    6310     # len(by) == 1
#    6312     by = by[0]
# ...

# %%
states = states.sort_values('0').reset_index(drop=True)
states
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 states = states.sort_values('0').reset_index(drop=True)
#       2 states
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6313, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6309 elif len(by):
#    6310     # len(by) == 1
#    6312     by = by[0]
# -> 6313     k = self._get_label_or_level_values(by, axis=axis)
# ...

# %%
states
# Out:
#      0
# 0   NM
# 1   MD
# 2   FL
# 3   WA
# 4   NY
# 5   TX
# 6   CA
# 7   VA
# 8   MA
# 9   NJ
# 10  CO
# 11  IL
# 12  KY
# 13  OR
# 14  CT
# 15  MI
# 16  DC
# 17  OH
# 18  AL
# 19  MO
# 20  PA
# 21  GA
# 22  IN
# 23  LA
# 24  WI
# 25  NC
# 26  AZ
# 27  NE
# 28  MN
# 29  UT
# 30  TN
# 31  DE
# 32  ID
# 33  RI
# 34  IA
# 35  SC
# 36  KS

# %%
state_html = states.to_html()
print(state_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NM</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>MD</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>FL</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>WA</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NY</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>TX</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>CA</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>VA</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>MA</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>NJ</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>CO</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>IL</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>KY</td>
#     </tr>
#     <tr>
# ...
